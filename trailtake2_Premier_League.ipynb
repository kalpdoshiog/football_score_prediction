# %%
import pandas as pd

# %%
matches = pd.read_csv("Premier_League_21-24.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2023-08-13  16:30  Premier League  Matchweek 1  Sun  Away      D  1.0  1.0
# 1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Home      W  3.0  1.0
# 2  2023-08-27  16:30  Premier League  Matchweek 3  Sun  Away      W  2.0  1.0
# 3  2023-09-03  14:00  Premier League  Matchweek 4  Sun  Home      W  3.0  0.0
# 4  2023-09-16  12:30  Premier League  Matchweek 5  Sat  Away      W  3.0  1.0
#
#         opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0        Chelsea  ...  Match Report    NaN  13.0  1.0  17.8  0.0  0     0
# 1    Bournemouth  ...  Match Report    NaN  25.0  9.0  16.8  1.0  0     1
# 2  Newcastle Utd  ...  Match Report    NaN   9.0  4.0  17.2  1.0  0     0
# 3    Aston Villa  ...  Match Report    NaN  17.0  4.0  14.7  0.0  0     0
# 4         Wolves  ...  Match Report    NaN  16.0  5.0  15.8  0.0  0     0
#
#    season       team
# 0    2024  Liverpool
# 1    2024  Liverpool
# 2    2024  Liverpool
# 3    2024  Liverpool
# 4    2024  Liverpool
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (2810, 27)

# %%
38 * 20 * 4
# Out:
# 3040

# %%
matches["team"].value_counts()
# Out:
# team
# Liverpool                   141
# West Ham United             141
# Everton                     141
# Wolverhampton Wanderers     141
# Brighton and Hove Albion    141
# Newcastle United            141
# Crystal Palace              141
# Aston Villa                 141
# Manchester United           140
# Chelsea                     140
# Manchester City             140
# Arsenal                     140
# Tottenham Hotspur           140
# Leicester City              114
# Southampton                 114
# Leeds United                114
# Fulham                      103
# Brentford                   103
# Burnley                     102
# Nottingham Forest            65
# Sheffield United             64
# Bournemouth                  63
# Watford                      38
# Norwich City                 38
# West Bromwich Albion         38
# Luton Town                   26
# Name: count, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     80
# Matchweek 14    80
# Matchweek 25    80
# Matchweek 24    80
# Matchweek 23    80
# Matchweek 22    80
# Matchweek 21    80
# Matchweek 2     80
# Matchweek 19    80
# Matchweek 18    80
# Matchweek 16    80
# Matchweek 15    80
# Matchweek 20    80
# Matchweek 13    80
# Matchweek 3     80
# Matchweek 11    80
# Matchweek 12    80
# Matchweek 10    80
# Matchweek 9     80
# Matchweek 8     80
# Matchweek 7     80
# Matchweek 6     80
# Matchweek 5     80
# Matchweek 4     80
# Matchweek 26    78
# Matchweek 17    78
# Matchweek 27    74
# Matchweek 29    60
# Matchweek 30    60
# Matchweek 31    60
# Matchweek 33    60
# Matchweek 34    60
# Matchweek 28    60
# Matchweek 35    60
# Matchweek 36    60
# Matchweek 37    60
# Matchweek 32    60
# Matchweek 38    60
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2810 entries, 0 to 42
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2810 non-null   object
#  1   time          2810 non-null   object
#  2   comp          2810 non-null   object
#  3   round         2810 non-null   object
#  4   day           2810 non-null   object
#  5   venue         2810 non-null   object
#  6   result        2810 non-null   object
#  7   gf            2810 non-null   float64
#  8   ga            2810 non-null   float64
#  9   opponent      2810 non-null   object
#  10  xg            2810 non-null   float64
#  11  xga           2810 non-null   float64
#  12  poss          2810 non-null   float64
#  13  attendance    2112 non-null   float64
#  14  captain       2810 non-null   object
#  15  formation     2810 non-null   object
#  16  referee       2810 non-null   object
#  17  match report  2810 non-null   object
#  18  notes         0 non-null      float64
#  19  sh            2810 non-null   float64
#  20  sot           2810 non-null   float64
#  21  dist          2809 non-null   float64
#  22  fk            2810 non-null   float64
#  23  pk            2810 non-null   int64
#  24  pkatt         2810 non-null   int64
#  25  season        2810 non-null   int64
#  26  team          2810 non-null   object
# dtypes: float64(11), int64(3), object(13)
# memory usage: 614.7+ KB

# %%
matches.describe()
# Out:
#                 gf           ga           xg          xga         poss  \
# count  2810.000000  2810.000000  2810.000000  2810.000000  2810.000000
# mean      1.436655     1.436655     1.386762     1.386762    50.000712
# std       1.307375     1.307375     0.818278     0.818278    12.834933
# min       0.000000     0.000000     0.000000     0.000000    18.000000
# 25%       0.000000     0.000000     0.800000     0.800000    40.000000
# 50%       1.000000     1.000000     1.300000     1.300000    50.000000
# 75%       2.000000     2.000000     1.900000     1.900000    60.000000
# max       9.000000     9.000000     7.000000     7.000000    82.000000
#
#          attendance  notes           sh          sot         dist  \
# count   2112.000000    0.0  2810.000000  2810.000000  2809.000000
# mean   38501.814394    NaN    12.574377     4.209964    17.295692
# std    17225.929819    NaN     5.492250     2.436237     3.014237
# min     2000.000000    NaN     0.000000     0.000000     5.300000
# 25%    25961.000000    NaN     8.250000     2.000000    15.400000
# 50%    36422.000000    NaN    12.000000     4.000000    17.200000
# 75%    53042.500000    NaN    16.000000     6.000000    19.100000
# max    75546.000000    NaN    34.000000    15.000000    39.900000
#
#                 fk           pk        pkatt       season
# count  2810.000000  2810.000000  2810.000000  2810.000000
# mean      0.423132     0.116014     0.142705  2022.377224
# std       0.642590     0.339717     0.376308     1.074005
# min       0.000000     0.000000     0.000000  2021.000000
# 25%       0.000000     0.000000     0.000000  2021.000000
# 50%       0.000000     0.000000     0.000000  2022.000000
# 75%       1.000000     0.000000     0.000000  2023.000000
# max       4.000000     3.000000     3.000000  2024.000000

# %%
matches.isnull().sum().sum()
# Out:
# 3509

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+","", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2023-01-01']

# %%
test = matches[matches["date"] > '2023-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6064718162839249

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0    1
# actual
# 0           460  121
# 1           256  121

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.5

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Liverpool")

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1  2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2  2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3  2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4  2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 48 2021-05-08  20:15  Premier League  Matchweek 35  Sat  Home      W  2.0
# 49 2021-05-13  20:15  Premier League  Matchweek 34  Thu  Away      W  4.0
# 50 2021-05-16  16:30  Premier League  Matchweek 36  Sun  Away      W  2.0
# 51 2021-05-19  20:15  Premier League  Matchweek 37  Wed  Away      W  3.0
# 52 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  2.0
#
#      ga        opponent  ...   fk  pk  pkatt  season       team venue_code  \
# 0   1.0         Chelsea  ...  0.0   0      0    2024  Liverpool          0
# 1   1.0     Bournemouth  ...  1.0   0      1    2024  Liverpool          1
# 2   1.0   Newcastle Utd  ...  1.0   0      0    2024  Liverpool          0
# 3   0.0     Aston Villa  ...  0.0   0      0    2024  Liverpool          1
# 4   1.0          Wolves  ...  0.0   0      0    2024  Liverpool          0
# ..  ...             ...  ...  ...  ..    ...     ...        ...        ...
# 48  0.0     Southampton  ...  0.0   0      0    2021  Liverpool          1
# 49  2.0  Manchester Utd  ...  0.0   0      0    2021  Liverpool          0
# 50  1.0       West Brom  ...  1.0   0      0    2021  Liverpool          0
# 51  0.0         Burnley  ...  1.0   0      0    2021  Liverpool          0
# 52  0.0  Crystal Palace  ...  1.0   0      0    2021  Liverpool          1
#
#    opp_code hour  day_code  target
# 0         6   16         6       0
# 1         2   15         5       1
# 2        16   16         6       1
# 3         1   14         6       1
# 4        25   12         5       1
# ..      ...  ...       ...     ...
# 48       20   20         5       1
# 49       15   20         3       1
# 50       23   16         6       1
# 51        5   20         2       1
# 52        7   16         6       1
#
# [141 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf","ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 6  2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7  2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9  2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11 2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 35 2024-02-04  16:30  Premier League  Matchweek 23  Sun  Away      L  1.0
# 36 2024-02-10  15:00  Premier League  Matchweek 24  Sat  Home      W  3.0
# 37 2024-02-17  12:30  Premier League  Matchweek 25  Sat  Away      W  4.0
# 38 2024-02-21  19:30  Premier League  Matchweek 26  Wed  Home      W  4.0
# 41 2024-03-02  15:00  Premier League  Matchweek 27  Sat  Away      W  1.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 6   7.0      Aston Villa  ...         6       0    3.000000    1.333333
# 7   2.0          Everton  ...         5       0    2.333333    2.666667
# 9   1.0    Sheffield Utd  ...         5       1    2.333333    3.333333
# 11  1.0         West Ham  ...         5       1    2.000000    3.333333
# 13  1.0  Manchester City  ...         6       0    2.000000    1.333333
# ..  ...              ...  ...       ...     ...         ...         ...
# 35  3.0          Arsenal  ...         6       0    4.000000    1.000000
# 36  1.0          Burnley  ...         5       1    3.000000    1.333333
# 37  1.0        Brentford  ...         5       1    2.666667    1.666667
# 38  1.0       Luton Town  ...         2       1    2.666667    1.666667
# 41  0.0  Nott'ham Forest  ...         5       1    3.666667    1.000000
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 6   19.666667    5.666667    18.166667   0.333333    0.666667       0.666667
# 7   17.666667    7.000000    17.466667   0.666667    0.000000       0.000000
# 9   19.000000    8.000000    16.733333   1.000000    0.000000       0.000000
# 11  17.666667    7.000000    17.033333   1.333333    0.000000       0.000000
# 13  15.666667    5.666667    18.266667   1.333333    0.333333       0.333333
# ..        ...         ...          ...        ...         ...            ...
# 35  24.333333   10.666667    18.433333   0.666667    0.333333       1.000000
# 36  17.000000    7.000000    19.600000   0.666667    0.000000       0.333333
# 37  20.666667    8.000000    18.333333   0.666667    0.000000       0.333333
# 38  16.666667    6.333333    17.000000   0.333333    0.000000       0.000000
# 41  23.000000   10.333333    16.066667   0.333333    0.000000       0.000000
#
# [138 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# <ipython-input-40-d7a196cb9ce7>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 27 2024-02-04  14:00  Premier League  Matchweek 23
#                         28 2024-02-10  15:00  Premier League  Matchweek 24
#                         29 2024-02-17  15:00  Premier League  Matchweek 25
#                         30 2024-02-25  13:30  Premier League  Matchweek 26
#                         32 2024-03-02  15:00  Premier League  Matchweek 27
#
#                             day venue result   gf   ga         opponent  ...  \
# team                                                                     ...
# Arsenal                 6   Sun  Home      W  2.0  1.0    Sheffield Utd  ...
#                         7   Sat  Away      L  0.0  1.0  Manchester City  ...
#                         9   Sun  Home      L  0.0  1.0   Leicester City  ...
#                         11  Sun  Away      W  1.0  0.0   Manchester Utd  ...
#                         13  Sun  Home      L  0.0  3.0      Aston Villa  ...
# ...                         ...   ...    ...  ...  ...              ...  ...
# Wolverhampton Wanderers 27  Sun  Away      W  4.0  2.0          Chelsea  ...
#                         28  Sat  Home      L  0.0  2.0        Brentford  ...
#                         29  Sat  Away      W  2.0  1.0        Tottenham  ...
#                         30  Sun  Home      W  1.0  0.0    Sheffield Utd  ...
#                         32  Sat  Away      L  0.0  3.0    Newcastle Utd  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 6          6       1    2.000000    1.333333
#                         7          5       0    1.666667    1.666667
#                         9          6       0    1.000000    1.666667
#                         11         6       1    0.666667    1.000000
#                         13         6       0    0.333333    0.666667
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 27         6       1    2.000000    1.333333
#                         28         5       0    2.333333    2.000000
#                         29         5       1    2.333333    2.666667
#                         30         6       1    2.000000    1.666667
#                         32         5       0    1.000000    1.000000
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 6    8.000000    3.666667    14.633333   0.666667
#                         7    5.666667    3.666667    15.366667   0.000000
#                         9    7.000000    3.666667    16.566667   0.666667
#                         11   9.666667    4.000000    16.566667   1.000000
#                         13   9.666667    2.666667    19.333333   1.000000
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 27  11.666667    4.666667    16.200000   0.333333
#                         28  12.000000    4.666667    17.266667   1.000000
#                         29  15.000000    5.333333    16.800000   1.333333
#                         30  14.000000    6.000000    16.566667   1.000000
#                         32  14.000000    4.666667    15.900000   0.333333
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 6     0.000000       0.000000
#                         7     0.000000       0.000000
#                         9     0.000000       0.000000
#                         11    0.000000       0.000000
#                         13    0.333333       0.333333
# ...                                ...            ...
# Wolverhampton Wanderers 27    0.333333       0.333333
#                         28    0.666667       0.666667
#                         29    0.666667       0.666667
#                         30    0.333333       0.333333
#                         32    0.000000       0.000000
#
# [2729 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel("team")

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 27 2024-02-04  14:00  Premier League  Matchweek 23  Sun  Away      W  4.0
# 28 2024-02-10  15:00  Premier League  Matchweek 24  Sat  Home      L  0.0
# 29 2024-02-17  15:00  Premier League  Matchweek 25  Sat  Away      W  2.0
# 30 2024-02-25  13:30  Premier League  Matchweek 26  Sun  Home      W  1.0
# 32 2024-03-02  15:00  Premier League  Matchweek 27  Sat  Away      L  0.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 6   1.0    Sheffield Utd  ...         6       1    2.000000    1.333333
# 7   1.0  Manchester City  ...         5       0    1.666667    1.666667
# 9   1.0   Leicester City  ...         6       0    1.000000    1.666667
# 11  0.0   Manchester Utd  ...         6       1    0.666667    1.000000
# 13  3.0      Aston Villa  ...         6       0    0.333333    0.666667
# ..  ...              ...  ...       ...     ...         ...         ...
# 27  2.0          Chelsea  ...         6       1    2.000000    1.333333
# 28  2.0        Brentford  ...         5       0    2.333333    2.000000
# 29  1.0        Tottenham  ...         5       1    2.333333    2.666667
# 30  0.0    Sheffield Utd  ...         6       1    2.000000    1.666667
# 32  3.0    Newcastle Utd  ...         5       0    1.000000    1.000000
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 6    8.000000    3.666667    14.633333   0.666667    0.000000       0.000000
# 7    5.666667    3.666667    15.366667   0.000000    0.000000       0.000000
# 9    7.000000    3.666667    16.566667   0.666667    0.000000       0.000000
# 11   9.666667    4.000000    16.566667   1.000000    0.000000       0.000000
# 13   9.666667    2.666667    19.333333   1.000000    0.333333       0.333333
# ..        ...         ...          ...        ...         ...            ...
# 27  11.666667    4.666667    16.200000   0.333333    0.333333       0.333333
# 28  12.000000    4.666667    17.266667   1.000000    0.666667       0.666667
# 29  15.000000    5.333333    16.800000   1.333333    0.666667       0.666667
# 30  14.000000    6.000000    16.566667   1.000000    0.333333       0.333333
# 32  14.000000    4.666667    15.900000   0.333333    0.000000       0.000000
#
# [2729 rows x 40 columns]

# %%
 matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 2724 2024-02-04  14:00  Premier League  Matchweek 23  Sun  Away      W  4.0
# 2725 2024-02-10  15:00  Premier League  Matchweek 24  Sat  Home      L  0.0
# 2726 2024-02-17  15:00  Premier League  Matchweek 25  Sat  Away      W  2.0
# 2727 2024-02-25  13:30  Premier League  Matchweek 26  Sun  Home      W  1.0
# 2728 2024-03-02  15:00  Premier League  Matchweek 27  Sat  Away      L  0.0
#
#        ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0     1.0    Sheffield Utd  ...         6       1    2.000000    1.333333
# 1     1.0  Manchester City  ...         5       0    1.666667    1.666667
# 2     1.0   Leicester City  ...         6       0    1.000000    1.666667
# 3     0.0   Manchester Utd  ...         6       1    0.666667    1.000000
# 4     3.0      Aston Villa  ...         6       0    0.333333    0.666667
# ...   ...              ...  ...       ...     ...         ...         ...
# 2724  2.0          Chelsea  ...         6       1    2.000000    1.333333
# 2725  2.0        Brentford  ...         5       0    2.333333    2.000000
# 2726  1.0        Tottenham  ...         5       1    2.333333    2.666667
# 2727  0.0    Sheffield Utd  ...         6       1    2.000000    1.666667
# 2728  3.0    Newcastle Utd  ...         5       0    1.000000    1.000000
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0      8.000000    3.666667    14.633333   0.666667    0.000000       0.000000
# 1      5.666667    3.666667    15.366667   0.000000    0.000000       0.000000
# 2      7.000000    3.666667    16.566667   0.666667    0.000000       0.000000
# 3      9.666667    4.000000    16.566667   1.000000    0.000000       0.000000
# 4      9.666667    2.666667    19.333333   1.000000    0.333333       0.333333
# ...         ...         ...          ...        ...         ...            ...
# 2724  11.666667    4.666667    16.200000   0.333333    0.333333       0.333333
# 2725  12.000000    4.666667    17.266667   1.000000    0.666667       0.666667
# 2726  15.000000    5.333333    16.800000   1.333333    0.666667       0.666667
# 2727  14.000000    6.000000    16.566667   1.000000    0.333333       0.333333
# 2728  14.000000    4.666667    15.900000   0.333333    0.000000       0.000000
#
# [2729 rows x 40 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], prediction=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5683760683760684

# %%
combined
# Out:
#       actual  prediction
# 89         0           1
# 90         1           0
# 91         1           0
# 92         0           1
# 93         0           1
# ...      ...         ...
# 2724       1           0
# 2725       0           0
# 2726       1           0
# 2727       1           1
# 2728       0           0
#
# [955 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  prediction       date                     team        opponent  \
# 89         0           1 2023-01-03                  Arsenal   Newcastle Utd
# 90         1           0 2023-01-15                  Arsenal       Tottenham
# 91         1           0 2023-01-22                  Arsenal  Manchester Utd
# 92         0           1 2023-02-04                  Arsenal         Everton
# 93         0           1 2023-02-11                  Arsenal       Brentford
# ...      ...         ...        ...                      ...             ...
# 2724       1           0 2024-02-04  Wolverhampton Wanderers         Chelsea
# 2725       0           0 2024-02-10  Wolverhampton Wanderers       Brentford
# 2726       1           0 2024-02-17  Wolverhampton Wanderers       Tottenham
# 2727       1           1 2024-02-25  Wolverhampton Wanderers   Sheffield Utd
# 2728       0           0 2024-03-02  Wolverhampton Wanderers   Newcastle Utd
#
#      result
# 89        D
# 90        W
# 91        W
# 92        L
# 93        D
# ...     ...
# 2724      W
# 2725      L
# 2726      W
# 2727      W
# 2728      L
#
# [955 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "Manchester United": "Manchester Utd",
    "Brigton and Hove Albion": "Brigton",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
}
mapping = MissingDict(**map_values)

# %%
mapping["West Ham United"]
# Out:
# 'West Ham'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  prediction       date                     team        opponent  \
# 89         0           1 2023-01-03                  Arsenal   Newcastle Utd
# 90         1           0 2023-01-15                  Arsenal       Tottenham
# 91         1           0 2023-01-22                  Arsenal  Manchester Utd
# 92         0           1 2023-02-04                  Arsenal         Everton
# 93         0           1 2023-02-11                  Arsenal       Brentford
# ...      ...         ...        ...                      ...             ...
# 2724       1           0 2024-02-04  Wolverhampton Wanderers         Chelsea
# 2725       0           0 2024-02-10  Wolverhampton Wanderers       Brentford
# 2726       1           0 2024-02-17  Wolverhampton Wanderers       Tottenham
# 2727       1           1 2024-02-25  Wolverhampton Wanderers   Sheffield Utd
# 2728       0           0 2024-03-02  Wolverhampton Wanderers   Newcastle Utd
#
#      result new_team
# 89        D  Arsenal
# 90        W  Arsenal
# 91        W  Arsenal
# 92        L  Arsenal
# 93        D  Arsenal
# ...     ...      ...
# 2724      W   Wolves
# 2725      L   Wolves
# 2726      W   Wolves
# 2727      W   Wolves
# 2728      L   Wolves
#
# [955 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           0             1 2023-01-03                  Arsenal
# 1           1             0 2023-01-15                  Arsenal
# 2           1             0 2023-01-22                  Arsenal
# 3           0             1 2023-02-04                  Arsenal
# 4           0             1 2023-02-11                  Arsenal
# ..        ...           ...        ...                      ...
# 825         1             0 2024-02-04  Wolverhampton Wanderers
# 826         0             0 2024-02-10  Wolverhampton Wanderers
# 827         1             0 2024-02-17  Wolverhampton Wanderers
# 828         1             1 2024-02-25  Wolverhampton Wanderers
# 829         0             0 2024-03-02  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0     Newcastle Utd        D    Arsenal         0             0
# 1         Tottenham        W    Arsenal         0             0
# 2    Manchester Utd        W    Arsenal         0             1
# 3           Everton        L    Arsenal         1             0
# 4         Brentford        D    Arsenal         0             0
# ..              ...      ...        ...       ...           ...
# 825         Chelsea        W     Wolves         0             0
# 826       Brentford        L     Wolves         1             0
# 827       Tottenham        W     Wolves         0             1
# 828   Sheffield Utd        W     Wolves         0             0
# 829   Newcastle Utd        L     Wolves         1             0
#
#                 team_y opponent_y result_y        new_team_y
# 0     Newcastle United    Arsenal        D     Newcastle Utd
# 1    Tottenham Hotspur    Arsenal        L         Tottenham
# 2    Manchester United    Arsenal        L    Manchester Utd
# 3              Everton    Arsenal        W           Everton
# 4            Brentford    Arsenal        D         Brentford
# ..                 ...        ...      ...               ...
# 825            Chelsea     Wolves        L           Chelsea
# 826          Brentford     Wolves        W         Brentford
# 827  Tottenham Hotspur     Wolves        L         Tottenham
# 828   Sheffield United     Wolves        L  Sheffield United
# 829   Newcastle United     Wolves        W     Newcastle Utd
#
# [830 rows x 13 columns]

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0 )] ["actual_x"].value_counts()
# Out:
# actual_x
# 1    114
# 0     73
# Name: count, dtype: int64

# %%
114/187
# Out:
# 0.6096256684491979

# %%
matches.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team', 'venue_code', 'opp_code', 'hour', 'day_code',
#        'target'],
#       dtype='object')
