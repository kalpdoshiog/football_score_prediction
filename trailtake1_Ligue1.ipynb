# %%
import pandas as pd

# %%
matches = pd.read_csv("Ligue1_21-24.csv", index_col=0)

# %%
matches.head()
# Out:
#         date   time     comp        round  day venue result  gf  ga  opponent  \
# 0  8/12/2023  21:00  Ligue 1  Matchweek 1  Sat  Home      D   0   0   Lorient
# 1  8/19/2023  21:00  Ligue 1  Matchweek 2  Sat  Away      D   1   1  Toulouse
# 2  8/26/2023  21:00  Ligue 1  Matchweek 3  Sat  Home      W   3   1      Lens
# 3   9/3/2023  20:45  Ligue 1  Matchweek 4  Sun  Away      W   4   1      Lyon
# 4  9/15/2023  21:00  Ligue 1  Matchweek 5  Fri  Home      L   2   3      Nice
#
#    ...  match report  notes  sh  sot  dist fk pk pkatt  season  \
# 0  ...  Match Report    NaN  20    4  18.9  1  0     0    2024
# 1  ...  Match Report    NaN  15    2  15.9  0  1     1    2024
# 2  ...  Match Report    NaN  17    6  19.9  1  0     0    2024
# 3  ...  Match Report    NaN  21    7  16.0  0  1     1    2024
# 4  ...  Match Report    NaN  12    3  20.6  1  0     0    2024
#
#                   team
# 0  Paris Saint Germain
# 1  Paris Saint Germain
# 2  Paris Saint Germain
# 3  Paris Saint Germain
# 4  Paris Saint Germain
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (2700, 27)

# %%
38 * 20 * 4
# Out:
# 3040

# %%
matches["team"].value_counts()
# Out:
# team
# Paris Saint Germain    138
# Monaco                 138
# Lille                  138
# Marseille              138
# Reims                  138
# Strasbourg             137
# Lorient                137
# Montpellier            137
# Brest                  137
# Nantes                 137
# Lyon                   137
# Rennes                 137
# Lens                   137
# Nice                   137
# Angers                 114
# Clermont Foot          100
# Metz                    99
# Saint Etienne           76
# Bordeaux                76
# Troyes                  76
# Toulouse                61
# Nimes                   38
# Dijon                   38
# Ajaccio                 38
# Auxerre                 38
# Le Havre                23
# Name: count, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     78
# Matchweek 13    78
# Matchweek 23    78
# Matchweek 22    78
# Matchweek 21    78
# Matchweek 2     78
# Matchweek 19    78
# Matchweek 18    78
# Matchweek 17    78
# Matchweek 16    78
# Matchweek 15    78
# Matchweek 14    78
# Matchweek 20    78
# Matchweek 12    78
# Matchweek 6     78
# Matchweek 11    78
# Matchweek 3     78
# Matchweek 5     78
# Matchweek 4     78
# Matchweek 7     78
# Matchweek 8     78
# Matchweek 9     78
# Matchweek 10    78
# Matchweek 24    66
# Matchweek 32    60
# Matchweek 37    60
# Matchweek 36    60
# Matchweek 35    60
# Matchweek 34    60
# Matchweek 33    60
# Matchweek 26    60
# Matchweek 31    60
# Matchweek 30    60
# Matchweek 29    60
# Matchweek 28    60
# Matchweek 27    60
# Matchweek 25    60
# Matchweek 38    60
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss              int64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh                int64
# sot               int64
# dist            float64
# fk                int64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2700 entries, 0 to 38
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2700 non-null   object
#  1   time          2700 non-null   object
#  2   comp          2700 non-null   object
#  3   round         2700 non-null   object
#  4   day           2700 non-null   object
#  5   venue         2700 non-null   object
#  6   result        2700 non-null   object
#  7   gf            2700 non-null   int64
#  8   ga            2700 non-null   int64
#  9   opponent      2700 non-null   object
#  10  xg            2700 non-null   float64
#  11  xga           2700 non-null   float64
#  12  poss          2700 non-null   int64
#  13  attendance    1918 non-null   float64
#  14  captain       2700 non-null   object
#  15  formation     2700 non-null   object
#  16  referee       2700 non-null   object
#  17  match report  2700 non-null   object
#  18  notes         0 non-null      float64
#  19  sh            2700 non-null   int64
#  20  sot           2700 non-null   int64
#  21  dist          2699 non-null   float64
#  22  fk            2700 non-null   int64
#  23  pk            2700 non-null   int64
#  24  pkatt         2700 non-null   int64
#  25  season        2700 non-null   int64
#  26  team          2700 non-null   object
# dtypes: float64(5), int64(9), object(13)
# memory usage: 590.6+ KB

# %%
matches.describe()
# Out:
#                 gf           ga           xg          xga         poss  \
# count  2700.000000  2700.000000  2700.000000  2700.000000  2700.000000
# mean      1.376296     1.376296     1.347222     1.347222    50.000741
# std       1.212153     1.212153     0.771781     0.771781    10.684016
# min       0.000000     0.000000     0.000000     0.000000    20.000000
# 25%       0.000000     0.000000     0.800000     0.800000    42.000000
# 50%       1.000000     1.000000     1.200000     1.200000    50.000000
# 75%       2.000000     2.000000     1.800000     1.800000    58.000000
# max       7.000000     7.000000     5.400000     5.400000    80.000000
#
#          attendance  notes           sh          sot         dist  \
# count    1918.00000    0.0  2700.000000  2700.000000  2699.000000
# mean    23591.67049    NaN    11.905926     4.063333    18.076732
# std     15788.76247    NaN     4.879584     2.342336     3.306416
# min       280.00000    NaN     0.000000     0.000000     6.600000
# 25%     11585.50000    NaN     8.000000     2.000000    15.900000
# 50%     20163.00000    NaN    12.000000     4.000000    17.800000
# 75%     32446.50000    NaN    15.000000     6.000000    19.900000
# max    180707.00000    NaN    32.000000    14.000000    54.900000
#
#                 fk           pk        pkatt       season
# count  2700.000000  2700.000000  2700.000000  2700.000000
# mean      0.473333     0.150000     0.183333  2022.311111
# std       0.696969     0.383163     0.425324     1.043455
# min       0.000000     0.000000     0.000000  2021.000000
# 25%       0.000000     0.000000     0.000000  2021.000000
# 50%       0.000000     0.000000     0.000000  2022.000000
# 75%       1.000000     0.000000     0.000000  2023.000000
# max       4.000000     3.000000     3.000000  2024.000000

# %%
matches.isnull().sum().sum()
# Out:
# 3483

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                     int64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                       int64
# sot                      int64
# dist                   float64
# fk                       int64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+","", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2023-01-01']

# %%
test = matches[matches["date"] > '2023-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6155660377358491

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0    1
# actual
# 0           418  117
# 1           209  104

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.47058823529411764

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Paris Saint Germain")

# %%
group
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 0  2023-08-12  21:00  Ligue 1   Matchweek 1  Sat  Home      D   0   0
# 1  2023-08-19  21:00  Ligue 1   Matchweek 2  Sat  Away      D   1   1
# 2  2023-08-26  21:00  Ligue 1   Matchweek 3  Sat  Home      W   3   1
# 3  2023-09-03  20:45  Ligue 1   Matchweek 4  Sun  Away      W   4   1
# 4  2023-09-15  21:00  Ligue 1   Matchweek 5  Fri  Home      L   2   3
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 48 2021-04-24  17:00  Ligue 1  Matchweek 34  Sat  Away      W   3   1
# 50 2021-05-01  17:00  Ligue 1  Matchweek 35  Sat  Home      W   2   1
# 52 2021-05-09  21:00  Ligue 1  Matchweek 36  Sun  Away      D   1   1
# 54 2021-05-16  21:00  Ligue 1  Matchweek 37  Sun  Home      W   4   0
# 56 2021-05-23  21:00  Ligue 1  Matchweek 38  Sun  Away      W   2   0
#
#     opponent  ...  fk  pk  pkatt  season                 team venue_code  \
# 0    Lorient  ...   1   0      0    2024  Paris Saint Germain          1
# 1   Toulouse  ...   0   1      1    2024  Paris Saint Germain          0
# 2       Lens  ...   1   0      0    2024  Paris Saint Germain          1
# 3       Lyon  ...   0   1      1    2024  Paris Saint Germain          0
# 4       Nice  ...   1   0      0    2024  Paris Saint Germain          1
# ..       ...  ...  ..  ..    ...     ...                  ...        ...
# 48      Metz  ...   2   1      1    2021  Paris Saint Germain          0
# 50      Lens  ...   2   0      0    2021  Paris Saint Germain          1
# 52    Rennes  ...   0   1      1    2021  Paris Saint Germain          0
# 54     Reims  ...   0   1      1    2021  Paris Saint Germain          1
# 56     Brest  ...   1   0      1    2021  Paris Saint Germain          0
#
#    opp_code hour  day_code  target
# 0        10   21         5       0
# 1        24   21         5       0
# 2         8   21         5       1
# 3        11   20         6       1
# 4        17   21         4       0
# ..      ...  ...       ...     ...
# 48       13   17         5       1
# 50        8   17         5       1
# 52       21   21         6       0
# 54       20   21         6       1
# 56        4   21         6       1
#
# [138 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf","ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 3  2020-09-20  13:00  Ligue 1   Matchweek 4  Sun  Away      W   3   0
# 4  2020-09-27  21:00  Ligue 1   Matchweek 5  Sun  Away      W   2   0
# 5  2020-10-02  21:00  Ligue 1   Matchweek 6  Fri  Home      W   6   1
# 6  2020-10-16  21:00  Ligue 1   Matchweek 7  Fri  Away      W   4   0
# 8  2020-10-24  21:00  Ligue 1   Matchweek 8  Sat  Home      W   4   0
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 28 2024-02-02  21:00  Ligue 1  Matchweek 20  Fri  Away      W   2   1
# 30 2024-02-10  21:00  Ligue 1  Matchweek 21  Sat  Home      W   3   1
# 32 2024-02-17  21:00  Ligue 1  Matchweek 22  Sat  Away      W   2   0
# 33 2024-02-25  17:05  Ligue 1  Matchweek 23  Sun  Home      D   1   1
# 34 2024-03-01  21:00  Ligue 1  Matchweek 24  Fri  Away      D   0   0
#
#       opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 3         Nice  ...         6       1    0.333333    0.666667  14.000000
# 4        Reims  ...         6       1    1.333333    0.333333  15.666667
# 5       Angers  ...         4       1    2.000000    0.000000  18.000000
# 6        Nîmes  ...         4       1    3.666667    0.333333  17.333333
# 8        Dijon  ...         5       1    4.000000    0.333333  23.000000
# ..         ...  ...       ...     ...         ...         ...        ...
# 28  Strasbourg  ...         4       1    2.333333    1.000000  12.666667
# 30       Lille  ...         5       1    2.000000    1.000000  11.000000
# 32      Nantes  ...         5       1    2.333333    1.333333  11.333333
# 33      Rennes  ...         6       0    2.333333    0.666667  11.666667
# 34      Monaco  ...         4       0    2.000000    0.666667  13.666667
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 3     4.333333    19.133333   1.333333    0.000000       0.000000
# 4     5.666667    15.666667   1.000000    0.333333       0.333333
# 5     6.666667    15.400000   1.000000    0.333333       0.333333
# 6     8.000000    15.466667   1.000000    0.333333       0.333333
# 8    10.000000    16.300000   1.000000    0.000000       0.000000
# ..         ...          ...        ...         ...            ...
# 28    5.333333    15.766667   0.666667    0.000000       0.000000
# 30    5.000000    18.066667   0.333333    0.000000       0.333333
# 32    5.333333    18.600000   0.333333    0.000000       0.333333
# 33    4.333333    20.400000   0.333333    0.333333       0.666667
# 34    3.666667    19.100000   0.666667    0.666667       0.666667
#
# [135 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# <ipython-input-42-d7a196cb9ce7>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                  date   time     comp         round  day venue result  gf  ga  \
# team
# Ajaccio 3  2022-08-26  21:00  Ligue 1   Matchweek 4  Fri  Home      L   1   3
#         4  2022-08-31  19:00  Ligue 1   Matchweek 5  Wed  Away      L   0   2
#         5  2022-09-04  15:00  Ligue 1   Matchweek 6  Sun  Home      L   0   1
#         6  2022-09-11  15:00  Ligue 1   Matchweek 7  Sun  Home      L   0   1
#         7  2022-09-18  15:00  Ligue 1   Matchweek 8  Sun  Away      W   1   0
# ...               ...    ...      ...           ...  ...   ...    ...  ..  ..
# Troyes  34 2023-05-07  20:45  Ligue 1  Matchweek 34  Sun  Home      L   1   3
#         35 2023-05-14  15:00  Ligue 1  Matchweek 35  Sun  Away      L   0   4
#         36 2023-05-21  15:00  Ligue 1  Matchweek 36  Sun  Home      D   1   1
#         37 2023-05-27  21:00  Ligue 1  Matchweek 37  Sat  Away      L   1   2
#         38 2023-06-03  21:00  Ligue 1  Matchweek 38  Sat  Home      D   1   1
#
#                opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# team                     ...
# Ajaccio 3         Lille  ...         4       0    0.666667    1.333333
#         4   Montpellier  ...         2       0    0.666667    1.666667
#         5       Lorient  ...         6       0    0.666667    2.333333
#         6          Nice  ...         6       0    0.333333    2.000000
#         7         Brest  ...         6       1    0.000000    1.333333
# ...                 ...  ...       ...     ...         ...         ...
# Troyes  34    Paris S-G  ...         6       0    1.000000    2.000000
#         35       Rennes  ...         6       0    1.000000    2.000000
#         36   Strasbourg  ...         6       0    0.333333    2.666667
#         37       Angers  ...         5       0    0.666667    2.666667
#         38        Lille  ...         5       0    0.666667    2.333333
#
#            sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  \
# team
# Ajaccio 3    8.333333    2.333333    18.300000   0.000000    0.333333
#         4   10.666667    2.000000    17.500000   0.000000    0.000000
#         5   12.666667    1.333333    16.700000   0.333333    0.000000
#         6   15.000000    1.666667    17.766667   1.000000    0.000000
#         7   13.333333    2.000000    18.366667   1.000000    0.000000
# ...               ...         ...          ...        ...         ...
# Troyes  34   7.000000    3.666667    16.766667   0.333333    0.333333
#         35   8.000000    3.666667    15.233333   0.333333    0.333333
#         36   6.666667    2.666667    15.533333   0.333333    0.000000
#         37   6.333333    1.666667    16.366667   0.666667    0.000000
#         38   5.666667    2.000000    16.500000   0.666667    0.000000
#
#             pkatt_rolling
# team
# Ajaccio 3        0.666667
#         4        0.333333
#         5        0.333333
#         6        0.000000
#         7        0.000000
# ...                   ...
# Troyes  34       0.333333
#         35       0.333333
#         36       0.000000
#         37       0.000000
#         38       0.000000
#
# [2619 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel("team")

# %%
matches_rolling
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 3  2022-08-26  21:00  Ligue 1   Matchweek 4  Fri  Home      L   1   3
# 4  2022-08-31  19:00  Ligue 1   Matchweek 5  Wed  Away      L   0   2
# 5  2022-09-04  15:00  Ligue 1   Matchweek 6  Sun  Home      L   0   1
# 6  2022-09-11  15:00  Ligue 1   Matchweek 7  Sun  Home      L   0   1
# 7  2022-09-18  15:00  Ligue 1   Matchweek 8  Sun  Away      W   1   0
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 34 2023-05-07  20:45  Ligue 1  Matchweek 34  Sun  Home      L   1   3
# 35 2023-05-14  15:00  Ligue 1  Matchweek 35  Sun  Away      L   0   4
# 36 2023-05-21  15:00  Ligue 1  Matchweek 36  Sun  Home      D   1   1
# 37 2023-05-27  21:00  Ligue 1  Matchweek 37  Sat  Away      L   1   2
# 38 2023-06-03  21:00  Ligue 1  Matchweek 38  Sat  Home      D   1   1
#
#        opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 3         Lille  ...         4       0    0.666667    1.333333   8.333333
# 4   Montpellier  ...         2       0    0.666667    1.666667  10.666667
# 5       Lorient  ...         6       0    0.666667    2.333333  12.666667
# 6          Nice  ...         6       0    0.333333    2.000000  15.000000
# 7         Brest  ...         6       1    0.000000    1.333333  13.333333
# ..          ...  ...       ...     ...         ...         ...        ...
# 34    Paris S-G  ...         6       0    1.000000    2.000000   7.000000
# 35       Rennes  ...         6       0    1.000000    2.000000   8.000000
# 36   Strasbourg  ...         6       0    0.333333    2.666667   6.666667
# 37       Angers  ...         5       0    0.666667    2.666667   6.333333
# 38        Lille  ...         5       0    0.666667    2.333333   5.666667
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 3     2.333333    18.300000   0.000000    0.333333       0.666667
# 4     2.000000    17.500000   0.000000    0.000000       0.333333
# 5     1.333333    16.700000   0.333333    0.000000       0.333333
# 6     1.666667    17.766667   1.000000    0.000000       0.000000
# 7     2.000000    18.366667   1.000000    0.000000       0.000000
# ..         ...          ...        ...         ...            ...
# 34    3.666667    16.766667   0.333333    0.333333       0.333333
# 35    3.666667    15.233333   0.333333    0.333333       0.333333
# 36    2.666667    15.533333   0.333333    0.000000       0.000000
# 37    1.666667    16.366667   0.666667    0.000000       0.000000
# 38    2.000000    16.500000   0.666667    0.000000       0.000000
#
# [2619 rows x 40 columns]

# %%
 matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time     comp         round  day venue result  gf  ga  \
# 0    2022-08-26  21:00  Ligue 1   Matchweek 4  Fri  Home      L   1   3
# 1    2022-08-31  19:00  Ligue 1   Matchweek 5  Wed  Away      L   0   2
# 2    2022-09-04  15:00  Ligue 1   Matchweek 6  Sun  Home      L   0   1
# 3    2022-09-11  15:00  Ligue 1   Matchweek 7  Sun  Home      L   0   1
# 4    2022-09-18  15:00  Ligue 1   Matchweek 8  Sun  Away      W   1   0
# ...         ...    ...      ...           ...  ...   ...    ...  ..  ..
# 2614 2023-05-07  20:45  Ligue 1  Matchweek 34  Sun  Home      L   1   3
# 2615 2023-05-14  15:00  Ligue 1  Matchweek 35  Sun  Away      L   0   4
# 2616 2023-05-21  15:00  Ligue 1  Matchweek 36  Sun  Home      D   1   1
# 2617 2023-05-27  21:00  Ligue 1  Matchweek 37  Sat  Away      L   1   2
# 2618 2023-06-03  21:00  Ligue 1  Matchweek 38  Sat  Home      D   1   1
#
#          opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 0           Lille  ...         4       0    0.666667    1.333333   8.333333
# 1     Montpellier  ...         2       0    0.666667    1.666667  10.666667
# 2         Lorient  ...         6       0    0.666667    2.333333  12.666667
# 3            Nice  ...         6       0    0.333333    2.000000  15.000000
# 4           Brest  ...         6       1    0.000000    1.333333  13.333333
# ...           ...  ...       ...     ...         ...         ...        ...
# 2614    Paris S-G  ...         6       0    1.000000    2.000000   7.000000
# 2615       Rennes  ...         6       0    1.000000    2.000000   8.000000
# 2616   Strasbourg  ...         6       0    0.333333    2.666667   6.666667
# 2617       Angers  ...         5       0    0.666667    2.666667   6.333333
# 2618        Lille  ...         5       0    0.666667    2.333333   5.666667
#
#      sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0       2.333333    18.300000   0.000000    0.333333       0.666667
# 1       2.000000    17.500000   0.000000    0.000000       0.333333
# 2       1.333333    16.700000   0.333333    0.000000       0.333333
# 3       1.666667    17.766667   1.000000    0.000000       0.000000
# 4       2.000000    18.366667   1.000000    0.000000       0.000000
# ...          ...          ...        ...         ...            ...
# 2614    3.666667    16.766667   0.333333    0.333333       0.333333
# 2615    3.666667    15.233333   0.333333    0.333333       0.333333
# 2616    2.666667    15.533333   0.333333    0.000000       0.000000
# 2617    1.666667    16.366667   0.666667    0.000000       0.000000
# 2618    2.000000    16.500000   0.666667    0.000000       0.000000
#
# [2619 rows x 40 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01'] # Use data instead of matches
    test = data[data["date"] > '2023-01-01']  # Use data instead of matches
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], prediction=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5153374233128835
